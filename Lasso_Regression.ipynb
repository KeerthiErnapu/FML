# %% [markdown]
# <a href="https://colab.research.google.com/github/KeerthiErnapu/FML/blob/main/Lasso_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("/Boston.csv")
print(data)
# Out:
#      Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0             1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1             2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2             3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3             4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4             5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502         503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503         504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504         505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# 505         506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1
#
#      tax  ptratio   black  lstat  medv
# ...

# %%
data.head()
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0           1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1           2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2           3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3           4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4           5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
#
#    tax  ptratio   black  lstat  medv
# 0  296     15.3  396.90   4.98  24.0
# 1  242     17.8  396.90   9.14  21.6
# 2  242     17.8  392.83   4.03  34.7
# 3  222     18.7  394.63   2.94  33.4
# 4  222     18.7  396.90   5.33  36.2

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  506 non-null    int64
#  1   crim        506 non-null    float64
#  2   zn          506 non-null    float64
#  3   indus       506 non-null    float64
#  4   chas        506 non-null    int64
#  5   nox         506 non-null    float64
#  6   rm          506 non-null    float64
#  7   age         506 non-null    float64
#  8   dis         506 non-null    float64
#  9   rad         506 non-null    int64
#  10  tax         506 non-null    int64
#  11  ptratio     506 non-null    float64
#  12  black       506 non-null    float64
#  13  lstat       506 non-null    float64
#  14  medv        506 non-null    float64
# dtypes: float64(11), int64(4)
# memory usage: 59.4 KB

# %%
data.corr()
# Out:
#             Unnamed: 0      crim        zn     indus      chas       nox  \
# Unnamed: 0    1.000000  0.407407 -0.103393  0.399439 -0.003759  0.398736
# crim          0.407407  1.000000 -0.200469  0.406583 -0.055892  0.420972
# zn           -0.103393 -0.200469  1.000000 -0.533828 -0.042697 -0.516604
# indus         0.399439  0.406583 -0.533828  1.000000  0.062938  0.763651
# chas         -0.003759 -0.055892 -0.042697  0.062938  1.000000  0.091203
# nox           0.398736  0.420972 -0.516604  0.763651  0.091203  1.000000
# rm           -0.079971 -0.219247  0.311991 -0.391676  0.091251 -0.302188
# age           0.203784  0.352734 -0.569537  0.644779  0.086518  0.731470
# dis          -0.302211 -0.379670  0.664408 -0.708027 -0.099176 -0.769230
# rad           0.686002  0.625505 -0.311948  0.595129 -0.007368  0.611441
# tax           0.666626  0.582764 -0.314563  0.720760 -0.035587  0.668023
# ptratio       0.291074  0.289946 -0.391679  0.383248 -0.121515  0.188933
# ...

# %%
x=data.drop(["medv"],axis=1)
y=data["medv"].values
print(x.head())
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0           1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1           2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2           3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3           4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4           5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
#
#    tax  ptratio   black  lstat
# 0  296     15.3  396.90   4.98
# 1  242     17.8  396.90   9.14
# 2  242     17.8  392.83   4.03
# 3  222     18.7  394.63   2.94
# 4  222     18.7  396.90   5.33

# %%
from sklearn import linear_model
from sklearn.linear_model import Lasso
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42)
lasso=Lasso(alpha=0.2)
lasso.fit(x_train,y_train)
# Out:
#      Unnamed: 0      crim    zn  indus  chas    nox     rm    age     dis  \
# 173         174   0.09178   0.0   4.05     0  0.510  6.416   84.1  2.6463
# 274         275   0.05644  40.0   6.41     1  0.447  6.758   32.9  4.0776
# 491         492   0.10574   0.0  27.74     0  0.609  5.983   98.8  1.8681
# 72           73   0.09164   0.0  10.81     0  0.413  6.065    7.8  5.2873
# 452         453   5.09017   0.0  18.10     0  0.713  6.297   91.8  2.3682
# ..          ...       ...   ...    ...   ...    ...    ...    ...     ...
# 418         419  73.53410   0.0  18.10     0  0.679  5.957  100.0  1.8026
# 117         118   0.15098   0.0  10.01     0  0.547  6.021   82.6  2.7474
# 42           43   0.14150   0.0   6.91     0  0.448  6.169    6.6  5.7209
# 322         323   0.35114   0.0   7.38     0  0.493  6.041   49.9  4.7211
# 347         348   0.01870  85.0   4.15     0  0.429  6.516   27.7  8.5353
#
#      rad  tax  ptratio   black  lstat
# 173    5  296     16.6  395.50   9.04
# ...

# %%
y_pre=lasso.predict(x_test)
print(y_pre)
# Out:
# [28.43656473 32.98596555 13.01050694 25.57630348 19.6025916  22.04326343
#  17.06486081 13.9768275  21.40815205 20.02328809 21.03158039 19.33493747
#  -7.49337378 21.11414754 19.14556457 25.77105672 20.16632386  5.60118693
#  40.07944954 18.31658296 27.62013894 29.60877616 11.75450262 23.9069293
#  18.85459105 14.62017422 22.63755952 14.46798844 18.45407479 18.96905026
#  21.67370453 25.41820342 25.72057315 20.81188907 15.03170327 20.58583321
#  31.85830285 21.22215226 20.46310753 24.88998155 13.17837259 31.47721742
#  41.9258659  17.60275882 27.25196    17.90726821 14.71573304 26.17471194
#  19.27307778 31.43521965 22.26255545 33.75116802 16.64905036 26.732677
#  39.76611979 22.7140458  20.07587825 32.72908218 25.21154811 12.65087628
#  24.28035684 32.17788063 32.08407702 17.89255694 21.5058954  12.38501296
#  20.83668632 26.60605725 31.88434964 11.93616333 20.71341508 26.32857449
#  11.45213612 18.21538033 23.15762707  5.47486473 21.58297991 40.65680551
# ...

# %%
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error
a=mean_squared_error(y_test,y_pre)
b=mean_absolute_error(y_test,y_pre)
c=r2_score(y_test,y_pre)
print(a,b,c)
# Out:
# 23.58648037708716 3.1849098294526943 0.6631808874922872
